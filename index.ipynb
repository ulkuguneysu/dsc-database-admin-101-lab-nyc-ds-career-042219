# %% [markdown]
# # Database Admin 101 - Lab
#
# ## Introduction
#
# In this lab you'll go through the process of designing and creating a database. From there, you'll also begin to populate this table with mock data provided to you.
#
# ## Objectives
#
# You will be able to:
#
# * Create a SQL database
# * Create a SQL table
# * Create rows in a SQL table
# * Alter entries in a SQL table
# * Delete entries in a SQL table
# * Commit changes via sqlite3

# %% [markdown]
# ## The Scenario
#
# You are looking to design a database for a school which will house various information from student grades to contact information, class roster lists and attendance. First, think of how you would design such a database and record some of your ideas below.

# %% [markdown]
# # Your Answer Here
#
# Record some information here about how you would design such a database. What table would you include? What columns would each table have? What would be the primary means to join said tables?

# %% [markdown]
# ## Creating the Database
#
# Now that you've put a little thought into how you might design your database, it's time to go ahead and create it! Start by import the necessary packages. Then, create a database called **school.sqlite**.

# %%
#Your code here; import necessary packages
import sqlite3 
import pandas as pd
import numpy as np

# %%
#Your code here; create the database school.sqlite
conn = sqlite3.connect('school.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Create a Table for Contact Information
#
# Create a table called contactInfo to house contact information for both students and staff. Be sure to include columns for first name, last name, role (student/staff), email, telephone number, street, city, state and zipcode. Be sure to also create a primary key for the table.

# %%
#Your code here
c.execute("""CREATE TABLE contactinfo (
                                id PRIMARYKEY INTEGER,
                                firstName TEXT,
                                lastName TEXT,
                                role TEXT,
                                email TEXT,
                                phone INTEGER,
                                street TEXT,
                                city TEXT,
                                state TEXT,
                                zipcode TEXT);
            """)
# Out:
# OperationalErrorTraceback (most recent call last)
# <ipython-input-4-88bf460896a6> in <module>()
#      11                                 state TEXT,
#      12                                 zipcode TEXT);
# ---> 13             """)
#
# OperationalError: table contactinfo already exists

# %% [markdown]
# ## Populate the Table
#
# Below, code is provided for you in order to load a list of dictionaries. Briefly examine the list. Each dictionary in the list will serve as an entry for your contact info table. Once you've briefly investigated the structure of this data, write a for loop to iterate through the list and create an entry in your table for each person's contact info.

# %%
# Code to load the list of dictionaries; just run this cell
import pickle

with open('contact_list.pickle', 'rb') as f:
    contacts = pickle.load(f)

# %%
for contact in contacts:
    firstName = contact['firstName']
    lastName = contact['lastName']
    role = contact['role']
    phone  = contact['telephone ']
    street = contact['street']
    city = contact['city']
    state = contact['state']
    zipcode  = contact['zipcode ']
    c.execute("""INSERT INTO contactInfo (firstName, lastName, role, phone, street, city, state, zipcode) 
                  VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}');
            """.format(firstName, lastName, role, phone, street, city, state, zipcode)
           )

# %%
# Query the Table to Ensure it is populated

import pandas as pd

c.execute("""select * from contactinfo order by firstName;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#       id    firstName  lastName     role email       phone  \
# 0   None       Andrew     Stepp  student  None  7866419252
# 1   None       Andrew     Stepp  student  None  7866419252
# 2   None       Andrew     Stepp  student  None  7866419252
# 3   None    Christine    Holden    staff  None  2035687697
# 4   None    Christine    Holden    staff  None  2035687697
# 5   None    Christine    Holden    staff  None  2035687697
# 6   None  Christopher    Warren  student  None  2175150957
# 7   None  Christopher    Warren  student  None  2175150957
# 8   None  Christopher    Warren  student  None  2175150957
# 9   None           Ed     Lyman  student  None  5179695576
# 10  None           Ed     Lyman  student  None  5179695576
# 11  None           Ed     Lyman  student  None  5179695576
# 12  None         Jane     Evans  student  None  3259909290
# 13  None         Jane     Evans  student  None  3259909290
# 14  None         Jane     Evans  student  None  3259909290
# 15  None         Jane     Evans  student  None  3259909290
# 16  None         Jane     Evans  student  None  3259909290
# 17  None         Jane     Evans  student  None  3259909290
# 18  None        Linda  Jacobson    staff  None  4049446441
# 19  None        Linda  Jacobson    staff  None  4049446441
# 20  None        Linda  Jacobson    staff  None  4049446441
# 21  None         Mary    Raines  student  None  9075772295
# 22  None         Mary    Raines  student  None  9075772295
# 23  None         Mary    Raines  student  None  9075772295
#
#                        street       city state zipcode
# 0   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 1   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 2   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 3          1672 Whitman Court   Stamford    CT   06995
# 4          1672 Whitman Court   Stamford    CT   06995
# 5          1672 Whitman Court   Stamford    CT   06995
# 6   1935 University Hill Road  Champaign    IL   61938
# 7   1935 University Hill Road  Champaign    IL   61938
# 8   1935 University Hill Road  Champaign    IL   61938
# 9               3478 Be Sreet    Lansing    MI   48933
# 10              3478 Be Sreet    Lansing    MI   48933
# 11              3478 Be Sreet    Lansing    MI   48933
# 12        1461 Briarhill Lane    Abilene    TX   79602
# 13        1461 Briarhill Lane    Abilene    TX   79602
# 14        1461 Briarhill Lane    Abilene    TX   79602
# 15        1461 Briarhill Lane    Abilene    TX   79602
# 16        1461 Briarhill Lane    Abilene    TX   79602
# 17        1461 Briarhill Lane    Abilene    TX   79602
# 18        479 Musgrave Street    Atlanta    GA   30303
# 19        479 Musgrave Street    Atlanta    GA   30303
# 20        479 Musgrave Street    Atlanta    GA   30303
# 21      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 22      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 23      3975 Jerry Toth Drive  Ninilchik    AK   99639

# %%
#Your code here
conn.commit()

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Persist your changes by committing them to the database.

# %%
#Your code here

# %% [markdown]
# ## Create a Table for Student Grades
#
# Create a new table in the database called "grades". In the table, include the following fields: userId, courseId, grade.
#
# ** This problem is a bit more tricky and will require a dual key. (A nuance you have yet to see.)
# Here's how to do that:
#
# ```SQL
# CREATE TABLE table_name(
#    column_1 INTEGER NOT NULL,
#    column_2 INTEGER NOT NULL,
#    ...
#    PRIMARY KEY(column_1,column_2,...)
# );
# ```

# %%
#Your code here; create the grades table.
c.execute("""CREATE TABLE grades (userId INTEGER NOT NULL,
                                  courseID INTEGER NOT NULL,
                                  grade INTEGER,
                                  PRIMARY KEY(userId, courseId));
            """)
# Out:
# OperationalErrorTraceback (most recent call last)
# <ipython-input-11-0d42de978275> in <module>()
#       4                                   grade INTEGER,
#       5                                   PRIMARY KEY(userId, courseId));
# ----> 6             """)
#
# OperationalError: table grades already exists

# %% [markdown]
# ## Remove Duplicate Entries
#
# An analyst just realized that there is a duplicate entry in the contactInfo table! Find and remove it.

# %%
#Your code here; find the duplicate entry
#Your code here; find the duplicate entry
c.execute("""select firstName, lastName, phone,
                      count(*) from contactInfo
                      group by 1,2,3
                      having count(*) > 1;""").fetchall()
# Out:
# [('Andrew', 'Stepp', 7866419252, 3),
#  ('Christine', 'Holden', 2035687697, 3),
#  ('Christopher', 'Warren', 2175150957, 3),
#  ('Ed', 'Lyman', 5179695576, 3),
#  ('Jane', 'Evans', 3259909290, 6),
#  ('Linda', 'Jacobson', 4049446441, 3),
#  ('Mary', 'Raines', 9075772295, 3)]

# %%
#Your code here; delete the duplicate entry
c.execute('''DELETE FROM contactInfo WHERE phone in (7866419252,
                                                    2035687697,
                                                    2175150957,
                                                    5179695576,
                                                    3259909290,
                                                    4049446441,
                                                    9075772295
                                                    ) ;''')

# %%
#Your code here; check that the duplicate entry was removed.
#Your code here; find the duplicate entry
c.execute("""select firstName, lastName, phone,
                      count(*) from contactInfo
                      group by 1,2,3
                      having count(*) > 1;""").fetchall()
# Out:
# []

# %% [markdown]
# ## Updating an Address
#
# Ed Lyman just moved to 2910 Simpson Avenue York, PA 17403. Update his address accordingly.

# %%
#Your code here; update Ed's address
# Ed	Lyman	student	None	5179695576	3478 Be Sreet	Lansing	MI	48933
c.execute("""UPDATE contactInfo
            SET """)

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Once again, persist your changes by committing them to the database.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# While there's certainly more to do with setting up and managing this database, you certainly got a taste for creating, populating and maintaining databases! Feel free to continue fleshing out this exercise to continue practicing.
